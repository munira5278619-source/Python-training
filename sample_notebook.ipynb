# %% [markdown]
# # My First Jupyter Notebook
# This is a sample notebook created for testing Binder.

# %%
print('Hello, Jupyter!')

# %%
# Simple math operation
result = 5 + 3
print('5 + 3 =', result)

# %%
# Plotting a simple graph
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [i**2 for i in x]
plt.plot(x, y)
plt.title('Simple Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
